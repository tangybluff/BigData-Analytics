# %% [markdown]
# ### BIG DATA: Media aritmética y varianza

# %%
import numpy as np
import pandas as pd # Manipulation for dataframes
import matplotlib.pyplot as plt # To make tables

# %%
# Crear los datos de columna x1; this data is invented 
datos = {'x1':[10.2, 10.6, 10.4, 10.8, 10, 9.8, 9.4, 9.6, 9.2, 10]}
# Crear el dataframe
df = pd.DataFrame(datos)
# Crear los datos de columna x2
df["x2"] = [11, 13, 12, 14, 10, 9, 7, 8, 6, 10]
# echar un vistazo
df
# Out:
#      x1  x2
# 0  10.2  11
# 1  10.6  13
# 2  10.4  12
# 3  10.8  14
# 4  10.0  10
# 5   9.8   9
# 6   9.4   7
# 7   9.6   8
# 8   9.2   6
# 9  10.0  10

# %%
# 'punto de partida' ; this is for basic plotting and you can copy and paste it
fig = plt.figure(figsize=(14, 8))
plt.plot(df.index, df["x1"], color="blue", marker="o")
plt.plot(df.index, df["x2"], color="orange", marker="o")
plt.axhline(y = df["x2"].mean(), color = 'r', linestyle = '-')
plt.xticks([])
plt.yticks(fontsize=20)
plt.legend(["x1", "x2","media aritmética"], loc ="upper right", fontsize=22);

# %%
# This is a function of pandas at the end; we do this for the column x1
print("Media aritmética de x1:   ", df["x1"].mean())
print("varianza de x1:           ", df["x1"].var())
print("desviación estándar de x1:", df["x1"].std())
# Out:
# Media aritmética de x1:    10.0
# varianza de x1:            0.26666666666666683
# desviación estándar de x1: 0.5163977794943224

# %%
# This is done for column x2
print("Media aritmética de x2:   ", df["x2"].mean())
print("varianza de x2:           ", df["x2"].var())
print("desviación estándar de x2:", df["x2"].std())
# Out:
# Media aritmética de x2:    10.0
# varianza de x2:            6.666666666666667
# desviación estándar de x2: 2.581988897471611
